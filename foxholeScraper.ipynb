# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
import os
import pandas as pd
import re

# %%
# https://medium.com/@tgcajal/beautiful-soup-template-and-example-for-python-web-scraping-355ccfe9eca
# target = https://foxhole.fandom.com/wiki/Vehicle_Health

url = 'https://foxhole.fandom.com/wiki/Vehicle_Health'
req = Request(url=url,headers={'user-agent': 'my-app/0.0.1'})
response = urlopen(req)
html = BeautifulSoup(response)

# %%
# https://stackoverflow.com/questions/2612548/extracting-an-attribute-value-with-beautifulsoup
# html.find_all("td")[0].contents[0]['title']
# html.find_all("td")[0]

# and not lazy load
# https://stackoverflow.com/questions/72101322/how-to-extract-title-of-a-tag-from-a-table-td-in-beautifulsoup
html.find_all('td')
# Out:
# [<td><a href="/wiki/Silverhand_-_Mk._IV" title="Silverhand - Mk. IV"><img alt="Silverhand - Mk. IV Vehicle Icon.png" class="lazyload" data-image-key="Silverhand_-_Mk._IV_Vehicle_Icon.png" data-image-name="Silverhand - Mk. IV Vehicle Icon.png" data-src="https://static.wikia.nocookie.net/foxhole_gamepedia_en/images/9/91/Silverhand_-_Mk._IV_Vehicle_Icon.png/revision/latest/scale-to-width-down/50?cb=20200906212249" decoding="async" height="50" loading="lazy" src="...%3D%3D" width="50"/></a>
#  </td>,
#  <td><a href="/wiki/Silverhand_-_Mk._IV" title="Silverhand - Mk. IV">Silverhand - Mk. IV</a>
#  </td>,
#  <td><a href="/wiki/Assault_Tank" title="Assault Tank">Assault Tank</a>
#  </td>,
#  <td>3100
#  </td>,
#  <td bgcolor="#172500"><font color="#777777">2170</font><hr/>3100
#  </td>,
#  <td bgcolor="#172500"><font color="#777777">2170</font><hr/>3100
#  </td>,
#  <td bgcolor="#172500"><font color="#777777">2170</font><hr/>3100
#  </td>,
# ...

# %%
for idx, table_title in enumerate(html.find_all('td')):
	print(table_title)
# Out:
# <td><a href="/wiki/Silverhand_-_Mk._IV" title="Silverhand - Mk. IV"><img alt="Silverhand - Mk. IV Vehicle Icon.png" class="lazyload" data-image-key="Silverhand_-_Mk._IV_Vehicle_Icon.png" data-image-name="Silverhand - Mk. IV Vehicle Icon.png" data-src="https://static.wikia.nocookie.net/foxhole_gamepedia_en/images/9/91/Silverhand_-_Mk._IV_Vehicle_Icon.png/revision/latest/scale-to-width-down/50?cb=20200906212249" decoding="async" height="50" loading="lazy" src="...%3D%3D" width="50"/></a>
# </td>
# <td><a href="/wiki/Silverhand_-_Mk._IV" title="Silverhand - Mk. IV">Silverhand - Mk. IV</a>
# </td>
# <td><a href="/wiki/Assault_Tank" title="Assault Tank">Assault Tank</a>
# </td>
# <td>3100
# </td>
# <td bgcolor="#172500"><font color="#777777">2170</font><hr/>3100
# </td>
# <td bgcolor="#172500"><font color="#777777">2170</font><hr/>3100
# </td>
# <td bgcolor="#172500"><font color="#777777">2170</font><hr/>3100
# </td>
# <td bgcolor="#172500"><font color="#777777">2170</font><hr/>3100
# ...

# %%
# html.select('td')
# html.find_all('td', {'class': 'lazyload'})
# html.find_all('td')
# html.find_all(['td','img'])
# html.find("td").find_all("a")[0]['title']
# html.find("td").find_all("a")
# html.select('td, img')
html.find_all('td')
# Out:
# [<td><a href="/wiki/Silverhand_-_Mk._IV" title="Silverhand - Mk. IV"><img alt="Silverhand - Mk. IV Vehicle Icon.png" class="lazyload" data-image-key="Silverhand_-_Mk._IV_Vehicle_Icon.png" data-image-name="Silverhand - Mk. IV Vehicle Icon.png" data-src="https://static.wikia.nocookie.net/foxhole_gamepedia_en/images/9/91/Silverhand_-_Mk._IV_Vehicle_Icon.png/revision/latest/scale-to-width-down/50?cb=20200906212249" decoding="async" height="50" loading="lazy" src="...%3D%3D" width="50"/></a>
#  </td>,
#  <td><a href="/wiki/Silverhand_-_Mk._IV" title="Silverhand - Mk. IV">Silverhand - Mk. IV</a>
#  </td>,
#  <td><a href="/wiki/Assault_Tank" title="Assault Tank">Assault Tank</a>
#  </td>,
#  <td>3100
#  </td>,
#  <td bgcolor="#172500"><font color="#777777">2170</font><hr/>3100
#  </td>,
#  <td bgcolor="#172500"><font color="#777777">2170</font><hr/>3100
#  </td>,
#  <td bgcolor="#172500"><font color="#777777">2170</font><hr/>3100
#  </td>,
# ...

# %%
for idx, table_title in enumerate(html.find_all('td')):
    print(table_title)
# Out:
# <td><a href="/wiki/Silverhand_-_Mk._IV" title="Silverhand - Mk. IV"><img alt="Silverhand - Mk. IV Vehicle Icon.png" class="lazyload" data-image-key="Silverhand_-_Mk._IV_Vehicle_Icon.png" data-image-name="Silverhand - Mk. IV Vehicle Icon.png" data-src="https://static.wikia.nocookie.net/foxhole_gamepedia_en/images/9/91/Silverhand_-_Mk._IV_Vehicle_Icon.png/revision/latest/scale-to-width-down/50?cb=20200906212249" decoding="async" height="50" loading="lazy" src="...%3D%3D" width="50"/></a>
# </td>
# <td><a href="/wiki/Silverhand_-_Mk._IV" title="Silverhand - Mk. IV">Silverhand - Mk. IV</a>
# </td>
# <td><a href="/wiki/Assault_Tank" title="Assault Tank">Assault Tank</a>
# </td>
# <td>3100
# </td>
# <td bgcolor="#172500"><font color="#777777">2170</font><hr/>3100
# </td>
# <td bgcolor="#172500"><font color="#777777">2170</font><hr/>3100
# </td>
# <td bgcolor="#172500"><font color="#777777">2170</font><hr/>3100
# </td>
# <td bgcolor="#172500"><font color="#777777">2170</font><hr/>3100
# ...
